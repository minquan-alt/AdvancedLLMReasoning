# %%
import sys
sys.path.append('..')  # or sys.path.append('..')
from datasets import load_from_disk
from data_utils.process_data import DataPreprocessing
from data_utils.prepare_data import prepare_dataset
from transformers import AutoTokenizer

# %%
data_path = '../data/subset_openmathinstruct_1'
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-1B")
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

# %%
train_dataset, dev_dataset, test_dataset = prepare_dataset('../data/subset_openmathinstruct_1/256K', tokenizer)
# Out:
# ...
# Map:   0%|          | 0/51200 [00:00<?, ? examples/s]

# %%
import torch
import os

data_path = 'D:/Learning/cs431/AdvancedLLMReasoning/data/subset_openmathinstruct_1/256K/processed_datasets'
os.makedirs(data_path, exist_ok=True)

torch.save(train_dataset, os.path.join(data_path, 'train_dataset.pt'))
torch.save(dev_dataset, os.path.join(data_path, 'dev_dataset.pt'))
torch.save(test_dataset, os.path.join(data_path, 'test_dataset.pt'))
